# par: (4, 3)
# suma del par: 7
# conteo resultados favorables:618
# par: (3, 1)
# suma del par: 4
# conteo resultados favorables:619
# par: (5, 5)
# suma del par: 10
# conteo resultados favorables:620
# par: (2, 4)
# suma del par: 6
# conteo resultados favorables:621
# par: (1, 1)
# suma del par: 2
# conteo resultados favorables:622
# par: (2, 1)
# suma del par: 3
# conteo resultados favorables:622
# par: (6, 2)
# suma del par: 8
# conteo resultados favorables:623
# par: (1, 3)
# suma del par: 4
# conteo resultados favorables:624
# par: (4, 5)
# suma del par: 9
# conteo resultados favorables:625
# par: (5, 4)
# suma del par: 9
# conteo resultados favorables:626
# par: (6, 6)
# suma del par: 12
# conteo resultados favorables:627
# par: (1, 6)
# suma del par: 7
# conteo resultados favorables:627
# par: (5, 3)
# suma del par: 8
# conteo resultados favorables:628
# par: (1, 1)
# suma del par: 2
# conteo resultados favorables:629
# par: (6, 5)
# suma del par: 11
# conteo resultados favorables:630
# par: (5, 3)
# suma del par: 8
# conteo resultados favorables:631
# par: (5, 6)
# suma del par: 11
# conteo resultados favorables:632
# par: (4, 2)
# suma del par: 6
# conteo resultados favorables:633
# par: (4, 2)
# suma del par: 6
# conteo resultados favorables:634
# par: (5, 5)
# suma del par: 10
# conteo resultados favorables:635
# par: (6, 1)
# suma del par: 7
# conteo resultados favorables:635
# par: (3, 1)
# suma del par: 4
# conteo resultados favorables:636
# par: (6, 3)
# suma del par: 9
# conteo resultados favorables:637
# par: (4, 3)
# suma del par: 7
# conteo resultados favorables:637
# par: (2, 1)
# suma del par: 3
# conteo resultados favorables:637
# par: (2, 6)
# suma del par: 8
# conteo resultados favorables:638
# par: (4, 5)
# suma del par: 9
# conteo resultados favorables:639
# par: (5, 1)
# suma del par: 6
# conteo resultados favorables:640
# par: (3, 2)
# suma del par: 5
# conteo resultados favorables:640
# par: (6, 5)
# suma del par: 11
# conteo resultados favorables:641
# par: (1, 3)
# suma del par: 4
# conteo resultados favorables:642
# Probabilidad empírica: 0.642 o 64.2%

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

            
# select random ball function:
def select_random_ball(dict):
    random_key = random.choice(list(dict.keys()))
    chosen = dict[random_key]
    return chosen

# select 3 random balls using previews function:
def select_5_random_balls():
    selected_balls = []
    for _ in range(5):
        ball = select_random_ball(ball_box)
        selected_balls.append(ball)
    return selected_balls

#perform simulation from instructions:
three_white_two_red = 0
all_the_same = 0
for _ in range(1000):   
    white = 0
    red = 0
    green = 0
    selection = select_5_random_balls()
    for element in selection:
        if element == "White":
            white+=1
        elif element == "Red":
            red+=1
        else:
            green+=1
    if white == 3 and red == 2:
        three_white_two_red+=1
    elif white==5 or red==5 or green==5:
        all_the_same+=1

print(f"3 white balls and 2 red balls: {three_white_two_red} times out of 1000")
print(f"Probability of getting 3 white balls and 2 red balls: {three_white_two_red/1000} or {(three_white_two_red/1000)*100}%")
print(f"All the same color: {all_the_same} times out of 1000")
print(f"Probability all the same color: {all_the_same/1000} or {(all_the_same/1000)*100}%")
# Out:
# 3 white balls and 2 red balls: 7 times out of 1000
# Probability of getting 3 white balls and 2 red balls: 0.007 or 0.7000000000000001%
# All the same color: 31 times out of 1000
# Probability all the same color: 0.031 or 3.1%
